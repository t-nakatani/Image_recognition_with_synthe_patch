# %%
import pandas as pd
import cv2
import numpy as np
from matplotlib import pyplot as plt
import os
import re

# %%
pred = pd.read_csv('../../img/pred_resnet50.csv', header = None)

# %%
pred
# Out:
#               0      1
# 0       0_0.png   True
# 1       0_1.png  False
# 2       0_2.png  False
# 3       0_3.png   True
# 4       0_4.png   True
# 5       0_5.png  False
# 6       0_6.png   True
# 7     100_0.png  False
# 8     100_1.png  False
# 9     100_2.png  False
# 10    100_3.png   True
# 11    100_4.png  False
# 12    101_0.png  False
# 13    101_1.png   True
# 14    101_2.png  False
# 15    101_3.png   True
# 16    101_4.png  False
# 17    101_5.png   True
# 18    101_6.png  False
# 19    101_7.png  False
# 20    102_0.png  False
# 21    102_1.png  False
# 22    102_2.png   True
# 23    102_3.png  False
# 24    102_4.png   True
# 25    103_0.png   True
# 26    103_1.png  False
# 27    103_2.png   True
# 28    103_3.png  False
# 29    103_4.png   True
# ...         ...    ...
# 1606   95_1.png  False
# 1607   95_2.png   True
# 1608   95_3.png   True
# 1609   95_4.png   True
# 1610   95_5.png   True
# 1611   96_0.png   True
# 1612   96_1.png   True
# 1613   96_2.png  False
# ...
